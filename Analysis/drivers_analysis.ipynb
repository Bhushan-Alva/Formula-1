# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %%
path = r"C:\Users\bhush\OneDrive\Desktop\DSMP\Formula 1\Overall"

circuits = pd.read_csv(os.path.join(path, "circuits.csv"))
constructor_results = pd.read_csv(os.path.join(path, "constructor_results.csv"))
constructor_standings = pd.read_csv(os.path.join(path, "constructor_standings.csv"))
constructors = pd.read_csv(os.path.join(path, "constructors.csv"))
driver_standings = pd.read_csv(os.path.join(path, "driver_standings.csv"))
drivers = pd.read_csv(os.path.join(path, "drivers.csv"))
lap_times = pd.read_csv(os.path.join(path, "lap_times.csv"))
pit_stops = pd.read_csv(os.path.join(path, "pit_stops.csv"))
qualifying = pd.read_csv(os.path.join(path, "qualifying.csv"))
races = pd.read_csv(os.path.join(path, "races.csv"))
results = pd.read_csv(os.path.join(path, "results.csv"))
seasons = pd.read_csv(os.path.join(path, "seasons.csv"))
sprint_results = pd.read_csv(os.path.join(path, "sprint_results.csv"))
status = pd.read_csv(os.path.join(path, "status.csv"))

# %%
drivers = drivers.replace(r"\N", np.nan, regex=False)
races = races.replace(r"\N", np.nan, regex=False)
results = results.replace(r"\N", np.nan, regex=False)

# %%
# driver table
drivers["number"] = pd.to_numeric(drivers["number"])
drivers["dob"] = pd.to_datetime(drivers["dob"], errors='coerce')


# races table
races_date_cols = ["date", "fp1_date", "fp2_date", "fp3_date", "quali_date", "sprint_date"]
races_time_cols = ["time", "fp1_time", "fp2_time", "fp3_time", "quali_time", "sprint_time"]

# Convert date columns
for col in races_date_cols:
    races[col] = pd.to_datetime(races[col], errors="coerce")

# Combine date + time into full datetime columns
for d_col, t_col in zip(races_date_cols, races_time_cols):
    new_col = d_col.replace("_date", "") + "_datetime"
    races[new_col] = pd.to_datetime(
        races[d_col].astype(str) + " " + races[t_col].astype(str),
        errors="coerce"
    )

# Drop original columns
races.drop(columns=races_time_cols, inplace=True)
races.drop(columns=races_date_cols, inplace=True)

# Rename main race datetime column
races.rename(columns={"date_datetime": "race_datetime"}, inplace=True)


# Results table
# Numeric with missing values → nullable integers
int_cols = ["number", "position", "milliseconds", "fastestLap", "rank"]
for col in int_cols:
    results[col] = pd.to_numeric(results[col], errors="coerce").astype("Int64")

# Float columns
results["fastestLapSpeed"] = pd.to_numeric(results["fastestLapSpeed"], errors="coerce")

# Convert fastest lap time to timedelta
def parse_lap_time(t):
    if pd.isna(t):
        return pd.NaT
    try:
        m, s = t.split(":")
        total_seconds = int(m) * 60 + float(s)
        return pd.to_timedelta(total_seconds, unit="s")
    except:
        return pd.NaT

results["fastestLapTime"] = results["fastestLapTime"].apply(parse_lap_time)

# Optional: convert positionText to category
results["positionText"] = results["positionText"].astype("category")

# %%
drivers["Driver Name"] = drivers["forename"] + " " + drivers["surname"]
drivers

# %% [markdown]
# ### Only Driver table

# %%
top_n = 20

counts = drivers["nationality"].value_counts().head(top_n)

plt.figure(figsize=(10, 6))
sns.barplot(
    x=counts.values,
    y=counts.index,
    palette="bright"
)

plt.title(f"Top {top_n} Nationalities by Number of F1 Drivers")
plt.xlabel("Number of Drivers")
plt.ylabel("Nationality")

# Add value labels
for i, v in enumerate(counts.values):
    plt.text(v + 0.3, i, str(v), va="center")

plt.tight_layout()
plt.show()

# %%
drivers["number"].value_counts()

# %%
drivers[drivers["number"] == 6]

# %%
drivers[~drivers["number"].isna()]

# %% [markdown]
# ### Driver + results

# %%
results

# %%
driver_results = results.merge(drivers, how="left", left_on="driverId", right_on="driverId")[['resultId', 'raceId', 'driverId', 'constructorId', 'grid',
       'position', 'positionText', 'positionOrder', 'points', 'laps',
       'milliseconds', 'fastestLap', 'rank', 'fastestLapTime', 'statusId', 'code', 'dob', 'nationality', 'Driver Name']]
driver_results

# %%
driver_results.info()

# %%
driver_results.info()

# %%
# Total driver points
driver_results.groupby("Driver Name")["points"].sum().sort_values(ascending=False)

# %%
# Total driver races
driver_results["Driver Name"].value_counts()

# %%
# points per race
(driver_results.groupby("Driver Name")["points"].sum() /
 driver_results["Driver Name"].value_counts()).sort_values(ascending=False)

# %%
# Most winners
driver_results[driver_results["positionOrder"] == 1]["Driver Name"].value_counts()

# %%
# Most 2nd place finish
driver_results[driver_results["positionOrder"] == 2]["Driver Name"].value_counts()

# %%
# Most 3rd place finish
driver_results[driver_results["positionOrder"] == 3]["Driver Name"].value_counts()

# %%
# Most podium finish
driver_results[(driver_results["positionOrder"] == 1) | (driver_results["positionOrder"] == 2) | (driver_results["positionOrder"] == 3)]["Driver Name"].value_counts()

# %%
# Start from results (FACT TABLE)
core_df = results.copy()

# 👤 Add Driver Info
core_df = core_df.merge(
    drivers[["driverId", "Driver Name", "code", "nationality", "dob"]],
    on="driverId",
    how="left"
)

# 📅 Add Race Context (time + circuitId)
core_df = core_df.merge(
    races[["raceId", "year", "round", "name", "race_datetime", "circuitId"]],
    on="raceId",
    how="left"
)

# 🏟️ Add Circuit / Location Info
core_df = core_df.merge(
    circuits[["circuitId", "name", "country"]],
    on="circuitId",
    how="left",
    suffixes=("", "_circuit")
)

# 🏎️ Add Constructor (Team) Info
core_df = core_df.merge(
    constructors[["constructorId", "name", "nationality"]],
    on="constructorId",
    how="left",
    suffixes=("", "_constructor")
)

# 🚦 Add Status Description (finish reason)
core_df = core_df.merge(
    status[["statusId", "status"]],
    on="statusId",
    how="left"
)


core_df = core_df.rename(columns={
    "name": "raceName",
    "name_circuit": "circuitName",
    "name_constructor": "constructorName",
    "nationality": "driverNationality",
    "nationality_constructor": "constructorNationality",
    "race_datetime": "raceDate",
    "status": "statusDescription",
    "positionOrder": "finishPosition",
    "grid": "gridPosition",
    "laps": "lapsCompleted",
    "milliseconds": "raceTime_ms"
})


core_df = core_df[[
    "raceId", "driverId", "constructorId",
    "Driver Name", "driverNationality", "dob",
    "constructorName",
    "year", "round", "raceName", "raceDate",
    "circuitName", "country",
    "gridPosition", "finishPosition", "points",
    "lapsCompleted", "raceTime_ms",
    "fastestLap", "fastestLapTime", "fastestLapSpeed",
    "statusDescription"
]]

core_df
# Out:
#        raceId  driverId  constructorId        Driver Name driverNationality  \
# 0          18         1              1     Lewis Hamilton           British
# 1          18         2              2      Nick Heidfeld            German
# 2          18         3              3       Nico Rosberg            German
# 3          18         4              4    Fernando Alonso           Spanish
# 4          18         5              1  Heikki Kovalainen           Finnish
# ...       ...       ...            ...                ...               ...
# 27233    1168       848              3    Alexander Albon              Thai
# 27234    1168       865            215       Isack Hadjar            French
# 27235    1168       859            215        Liam Lawson     New Zealander
# 27236    1168       842            214       Pierre Gasly            French
# 27237    1168       861            214   Franco Colapinto      Argentinian
#
#              dob constructorName  year  round               raceName  ...  \
# 0     1985-01-07         McLaren  2008      1  Australian Grand Prix  ...
# 1     1977-05-10      BMW Sauber  2008      1  Australian Grand Prix  ...
# 2     1985-06-27        Williams  2008      1  Australian Grand Prix  ...
# 3     1981-07-29         Renault  2008      1  Australian Grand Prix  ...
# 4     1981-10-19         McLaren  2008      1  Australian Grand Prix  ...
# ...          ...             ...   ...    ...                    ...  ...
# 27233 1996-03-23        Williams  2025     24   Abu Dhabi Grand Prix  ...
# 27234 2004-09-28      RB F1 Team  2025     24   Abu Dhabi Grand Prix  ...
# 27235 2002-02-11      RB F1 Team  2025     24   Abu Dhabi Grand Prix  ...
# 27236 1996-02-07  Alpine F1 Team  2025     24   Abu Dhabi Grand Prix  ...
# 27237 2003-05-27  Alpine F1 Team  2025     24   Abu Dhabi Grand Prix  ...
#
#          country gridPosition finishPosition  points  lapsCompleted  \
# 0      Australia            1              1    10.0             58
# 1      Australia            5              2     8.0             58
# 2      Australia            7              3     6.0             58
# 3      Australia           11              4     5.0             58
# 4      Australia            3              5     4.0             58
# ...          ...          ...            ...     ...            ...
# 27233        UAE           17             16     0.0             58
# 27234        UAE            9             17     0.0             57
# 27235        UAE           13             18     0.0             57
# 27236        UAE           19             19     0.0             57
# 27237        UAE           20             20     0.0             57
#
#        raceTime_ms  fastestLap         fastestLapTime  fastestLapSpeed  \
# 0          5690616          39 0 days 00:01:27.500000          218.300
# 1          5696094          41 0 days 00:01:27.700000          217.586
# 2          5698779          41 0 days 00:01:28.100000          216.719
# 3          5707797          58 0 days 00:01:28.600000          215.464
# 4          5708630          43 0 days 00:01:27.400000          218.385
# ...            ...         ...                    ...              ...
# 27233      5257796          45 0 days 00:01:28.400000              NaN
# 27234         <NA>          52 0 days 00:01:29.400000              NaN
# 27235         <NA>          39 0 days 00:01:28.900000              NaN
# 27236         <NA>          46 0 days 00:01:27.800000              NaN
# 27237         <NA>          42 0 days 00:01:27.700000              NaN
#
#       statusDescription
# 0              Finished
# 1              Finished
# 2              Finished
# 3              Finished
# 4              Finished
# ...                 ...
# 27233          Finished
# 27234            +1 Lap
# 27235            +1 Lap
# 27236            +1 Lap
# 27237            +1 Lap
#
# [27238 rows x 22 columns]

# %%
core_df.to_csv(os.path.join(path, "f1_driver_race_master.csv"), index=False)

# %%
core_df
# Out:
#        raceId  driverId  constructorId        Driver Name driverNationality  \
# 0          18         1              1     Lewis Hamilton           British
# 1          18         2              2      Nick Heidfeld            German
# 2          18         3              3       Nico Rosberg            German
# 3          18         4              4    Fernando Alonso           Spanish
# 4          18         5              1  Heikki Kovalainen           Finnish
# ...       ...       ...            ...                ...               ...
# 27233    1168       848              3    Alexander Albon              Thai
# 27234    1168       865            215       Isack Hadjar            French
# 27235    1168       859            215        Liam Lawson     New Zealander
# 27236    1168       842            214       Pierre Gasly            French
# 27237    1168       861            214   Franco Colapinto      Argentinian
#
#              dob constructorName  year  round               raceName  ...  \
# 0     1985-01-07         McLaren  2008      1  Australian Grand Prix  ...
# 1     1977-05-10      BMW Sauber  2008      1  Australian Grand Prix  ...
# 2     1985-06-27        Williams  2008      1  Australian Grand Prix  ...
# 3     1981-07-29         Renault  2008      1  Australian Grand Prix  ...
# 4     1981-10-19         McLaren  2008      1  Australian Grand Prix  ...
# ...          ...             ...   ...    ...                    ...  ...
# 27233 1996-03-23        Williams  2025     24   Abu Dhabi Grand Prix  ...
# 27234 2004-09-28      RB F1 Team  2025     24   Abu Dhabi Grand Prix  ...
# 27235 2002-02-11      RB F1 Team  2025     24   Abu Dhabi Grand Prix  ...
# 27236 1996-02-07  Alpine F1 Team  2025     24   Abu Dhabi Grand Prix  ...
# 27237 2003-05-27  Alpine F1 Team  2025     24   Abu Dhabi Grand Prix  ...
#
#          country gridPosition finishPosition  points  lapsCompleted  \
# 0      Australia            1              1    10.0             58
# 1      Australia            5              2     8.0             58
# 2      Australia            7              3     6.0             58
# 3      Australia           11              4     5.0             58
# 4      Australia            3              5     4.0             58
# ...          ...          ...            ...     ...            ...
# 27233        UAE           17             16     0.0             58
# 27234        UAE            9             17     0.0             57
# 27235        UAE           13             18     0.0             57
# 27236        UAE           19             19     0.0             57
# 27237        UAE           20             20     0.0             57
#
#        raceTime_ms  fastestLap         fastestLapTime  fastestLapSpeed  \
# 0          5690616          39 0 days 00:01:27.500000          218.300
# 1          5696094          41 0 days 00:01:27.700000          217.586
# 2          5698779          41 0 days 00:01:28.100000          216.719
# 3          5707797          58 0 days 00:01:28.600000          215.464
# 4          5708630          43 0 days 00:01:27.400000          218.385
# ...            ...         ...                    ...              ...
# 27233      5257796          45 0 days 00:01:28.400000              NaN
# 27234         <NA>          52 0 days 00:01:29.400000              NaN
# 27235         <NA>          39 0 days 00:01:28.900000              NaN
# 27236         <NA>          46 0 days 00:01:27.800000              NaN
# 27237         <NA>          42 0 days 00:01:27.700000              NaN
#
#       statusDescription
# 0              Finished
# 1              Finished
# 2              Finished
# 3              Finished
# 4              Finished
# ...                 ...
# 27233          Finished
# 27234            +1 Lap
# 27235            +1 Lap
# 27236            +1 Lap
# 27237            +1 Lap
#
# [27238 rows x 22 columns]

# %%
core_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27238 entries, 0 to 27237
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   raceId             27238 non-null  int64
#  1   driverId           27238 non-null  int64
#  2   constructorId      27238 non-null  int64
#  3   Driver Name        27238 non-null  object
#  4   driverNationality  27238 non-null  object
#  5   dob                27238 non-null  datetime64[ns]
#  6   constructorName    27238 non-null  object
#  7   year               27238 non-null  int64
#  8   round              27238 non-null  int64
#  9   raceName           27238 non-null  object
#  10  raceDate           8769 non-null   datetime64[ns]
#  11  circuitName        27238 non-null  object
#  12  country            27238 non-null  object
#  13  gridPosition       27238 non-null  int64
#  14  finishPosition     27238 non-null  int64
#  15  points             27238 non-null  float64
#  16  lapsCompleted      27238 non-null  int64
#  17  raceTime_ms        8021 non-null   Int64
#  18  fastestLap         8709 non-null   Int64
#  19  fastestLapTime     8709 non-null   timedelta64[ns]
#  20  fastestLapSpeed    8252 non-null   float64
#  21  statusDescription  27238 non-null  object
# dtypes: Int64(2), datetime64[ns](2), float64(2), int64(8), object(7), timedelta64[ns](1)
# memory usage: 4.6+ MB

# %%
core_df[core_df["raceTime_ms"].isna()]["year"].value_counts().sort_values()
# Out:
# year
# 2009    121
# 2023    134
# 1957    136
# 1969    139
# 1950    144
#        ...
# 1992    410
# 1988    422
# 1990    454
# 1991    454
# 1989    555
# Name: count, Length: 76, dtype: int64

# %%
core_df[["raceId", "driverId"]].duplicated().sum()
# Out:
# np.int64(91)

# %%
core_df[core_df[["raceId", "driverId"]].duplicated()].sort_values(["driverId", "raceId"])
# Out:
#        raceId  driverId  constructorId          Driver Name driverNationality  \
# 13191     540       229             57          Harald Ertl          Austrian
# 20287     779       356             87         Jack Brabham        Australian
# 24298     717       373            172            Jim Clark           British
# 24297     745       418            172       Masten Gregory          American
# 20244     792       427              6  Maurice Trintignant            French
# ...       ...       ...            ...                  ...               ...
# 20233     800       702            134            Bob Scott          American
# 20199     809       702            113            Bob Scott          American
# 20236     800       730            134        George Fonder          American
# 20192     823       759            105       Jan Flinterman             Dutch
# 20187     828       786             51        Luigi Fagioli           Italian
#
#              dob constructorName  year  round                  raceName  ...  \
# 13191 1948-08-31          Ensign  1978     14        Italian Grand Prix  ...
# 20287 1926-04-02          Cooper  1957      4         French Grand Prix  ...
# 24298 1936-03-04    Lotus-Climax  1964      9  United States Grand Prix  ...
# 24297 1932-02-29    Lotus-Climax  1961      8  United States Grand Prix  ...
# 20244 1917-10-30         Ferrari  1955      1      Argentine Grand Prix  ...
# ...          ...             ...   ...    ...                       ...  ...
# 20233 1928-10-04       Schroeder  1954      2          Indianapolis 500  ...
# 20199 1928-10-04    Kurtis Kraft  1953      2          Indianapolis 500  ...
# 20236 1917-06-22       Schroeder  1954      2          Indianapolis 500  ...
# 20192 1919-10-02        Maserati  1952      7          Dutch Grand Prix  ...
# 20187 1898-06-09      Alfa Romeo  1951      4         French Grand Prix  ...
#
#            country gridPosition finishPosition  points  lapsCompleted  \
# 13191        Italy            0             29     0.0              0
# 20287       France           15              7     0.0             68
# 24298          USA            1             12     0.0             54
# 24297          USA           15             11     0.0             92
# 20244    Argentina            1              2     2.0             96
# ...            ...          ...            ...     ...            ...
# 20233          USA           23             25     0.0            165
# 20199          USA           19             12     0.0            190
# 20236          USA           26             31     0.0            101
# 20192  Netherlands           16              9     0.0             83
# 20187       France            1             11     0.0             55
#
#        raceTime_ms  fastestLap  fastestLapTime  fastestLapSpeed  \
# 13191         <NA>        <NA>             NaT              NaN
# 20287         <NA>        <NA>             NaT              NaN
# 24298         <NA>        <NA>             NaT              NaN
# 24297         <NA>        <NA>             NaT              NaN
# 20244     10928200        <NA>             NaT              NaN
# ...            ...         ...             ...              ...
# 20233         <NA>        <NA>             NaT              NaN
# 20199         <NA>        <NA>             NaT              NaN
# 20236         <NA>        <NA>             NaT              NaN
# 20192         <NA>        <NA>             NaT              NaN
# 20187         <NA>        <NA>             NaT              NaN
#
#         statusDescription
# 13191  Did not prequalify
# 20287             +9 Laps
# 24298           Injection
# 24297             +8 Laps
# 20244            Finished
# ...                   ...
# 20233          Suspension
# 20199            +10 Laps
# 20236              Brakes
# 20192             +7 Laps
# 20187            +22 Laps
#
# [91 rows x 22 columns]

# %%
core_df[(core_df["raceId"] == 800) & (core_df["driverId"] == 612)]
# Out:
#        raceId  driverId  constructorId  Driver Name driverNationality  \
# 19255     800       612            134  Andy Linden          American
# 20219     800       612            113  Andy Linden          American
# 20231     800       612            138  Andy Linden          American
#
#              dob constructorName  year  round          raceName  ... country  \
# 19255 1922-04-05       Schroeder  1954      2  Indianapolis 500  ...     USA
# 20219 1922-04-05    Kurtis Kraft  1954      2  Indianapolis 500  ...     USA
# 20231 1922-04-05         Nichels  1954      2  Indianapolis 500  ...     USA
#
#       gridPosition finishPosition  points  lapsCompleted  raceTime_ms  \
# 19255           23             25     0.0            165         <NA>
# 20219           27             11     0.0            200     14259460
# 20231            4             24     0.0            165         <NA>
#
#        fastestLap  fastestLapTime  fastestLapSpeed statusDescription
# 19255        <NA>             NaT              NaN        Suspension
# 20219        <NA>             NaT              NaN          Finished
# 20231        <NA>             NaT              NaN           Retired
#
# [3 rows x 22 columns]

# %%
core_df[core_df["points"] == 50]
# Out:
#        raceId  driverId  constructorId     Driver Name driverNationality  \
# 22514     918         1            131  Lewis Hamilton           British
#
#              dob constructorName  year  round              raceName  ...  \
# 22514 1985-01-07        Mercedes  2014     19  Abu Dhabi Grand Prix  ...
#
#       country gridPosition finishPosition  points  lapsCompleted  raceTime_ms  \
# 22514     UAE            2              1    50.0             55      5942619
#
#        fastestLap         fastestLapTime  fastestLapSpeed statusDescription
# 22514          49 0 days 00:01:45.600000          189.342          Finished
#
# [1 rows x 22 columns]
